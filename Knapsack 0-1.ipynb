# %% [markdown]
# classic 0/1 Knapsack <br>
# https://www.hackerrank.com/contests/srin-aadc03/challenges/classic-01-knapsack/copy-from/1306097884 <br>
# Tried 2 implementations:
#   * recursive
#   * iterative
# The iterative one performed faster

# %%
#!/bin/python3

import sys

def iterativeKnapsack(k):    
    dyn_table = [[0]*(k+1) for i in range(len(arr)+1)]
    
    for i in range(1,len(arr)+1,1):
        #for each item
        
        for w in range(k+1):
            #for each weight
            weight, value = arr[i-1]
            if w - weight < 0:
                included = 0
            else:
                included = value + dyn_table[i-1][w-weight]
            excluded = dyn_table[i-1][w]
            dyn_table[i][w] = max(included, excluded)
    return dyn_table[-1][-1]
    
def unboundedKnapsack(k, idx):
    partial_sums = [-1]*(n+1)
    if idx < 0:
        return 0
    if partial_sums[idx] != -1:
        return partial_sums[idx]
    weight, value = arr[idx]
    if k-weight < 0:
        included = 0
    else:
        included = value + unboundedKnapsack(k-weight, idx-1)
    excluded = unboundedKnapsack(k, idx-1)
    return max(included, excluded)

# %%
#Hackerrank main
if __name__ == "__main__":
    t = int(input().strip())
    for _ in range(t):
        s, n = input().strip().split(' ')
        s, n = [int(s), int(n)]
        arr = []
        for _ in range(n):
            w, v = list(map(int, input().strip().split(' ')))
            arr.append((w, v))
        #result = unboundedKnapsack(s, len(arr)-1)
        result = iterativeKnapsack(s)
        print(result)

# %%
#My tests

if __name__ == "__main__":
    t = 9
    weights = [[[1, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[2, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[3, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[4, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[5, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[6, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[7, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[8, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]],[[9, 5],[1, 1],[2, 2],[2, 3],[2, 4],[2, 5]]]
    ground_truth = [1, 5, 6, 9, 10, 12, 13, 14, 15]
    for j in range(t):
        s, n = weights[j][0]
        arr = []
        for i in range(n):
            w, v = weights[j][i+1]
            arr.append((w, v))
        #result = unboundedKnapsack(s, len(arr)-1)
        result = iterativeKnapsack(s)
        assert ground_truth[j] == result 
    print('tests passed')
# Out:
# tests passed
